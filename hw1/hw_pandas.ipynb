# %% [markdown]
# ## Анализ причин выжимаемости на Титанике
#
# В качестве первого домашнего задания Вам предстоит сформулировать и проверить гипотезы о причинах выживаемости на Титанике. Необходимые данные можно найти на [GitHub](https://github.com/aleksei-riabykh/sberbank_data_analysis_06_07_21/tree/master/data/titanic) курса, описание к данным на сайте соревнований по анализу данных [Kaggle](https://www.kaggle.com/c/titanic/data).
#
# Критерии оценивания:
# * Четко сформулированы гипотезы и выводы из них
# * Гипотез не меньше 3-х
# * Присутствуют кросс-признаковые гипотезы (например, процент выживаемости среди молодых женщин: пол + возраст)
# * Использованы группировки `.groupby()` с агрегированием `.aggregate()`, трансформацией `.transform()` или фильтрацией  `.filter()` данных
# * Присутствует визуализация
# * Присутствует общий вывод исследования

# %%
import pandas as pd # импортируем Pandas
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()

# %%
# считываем данные
# https://www.kaggle.com/c/titanic/data

df = pd.read_csv('../data/titanic/train.csv')
df1= pd.read_csv('../data/titanic/train.csv')
df2= pd.read_csv('../data/titanic/train.csv')

# %% [markdown]
# ## Шаблон исследования

# %% [markdown]
# ### Гипотеза 1
#
# __Формулировка__:

# %% [markdown]
#   Выживаемость зависит от класса каюты и пола (В первую очередь в шлюпки сажали женщин затем нескольких мужчин в качестве гребцов, в первую очередь пассажиров 1 класса затем 2 и 3).

# %%
# Код для проверки гипотезы

df.Sex.replace({'male':'Мужчины', 'female':'Женщины'}, inplace=True)
fg1=pd.DataFrame(df.groupby(['Pclass', 'Sex'])['Survived'].aggregate(np.mean))

print(fg1)
# Out:
#                 Survived
# Pclass Sex
# 1      Женщины  0.968085
#        Мужчины  0.368852
# 2      Женщины  0.921053
#        Мужчины  0.157407
# 3      Женщины  0.500000
#        Мужчины  0.135447

# %%
sns.barplot(x='Sex', y='Survived', hue='Pclass', data=df)
plt.ylabel("Вероятность выжить")
plt.title("Вероятность выжить, как функция пола и класса каюты")
plt.show()

# %% [markdown]
# __Вывод__:Гипотеза подтверждена.
# Наибольшие шансы выжить имели женщины в первом классе, наименьшие  - мужчины в третьем.

# %% [markdown]
# ###  Гипотеза 2
#
# __Формулировка__: При соблюдении порядка размещения в шлюпки дети и старики имеют самый высокий шанс выживания

# %%
# Код для проверки гипотезы

###

# %%
def get_Age_GR(iAge):
    return {
        iAge < 12:  'Ребенок',
        12 <= iAge < 50:  'Взрослый',
        50 <= iAge :  'Старый'
    }[True]

# %%
fg1=df.dropna(subset=['Age'])
fg1['Age_Group']=fg1.Age.apply(lambda x: get_Age_GR(x))
# Out:
# <ipython-input-7-3eb8a1fbd2ee>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fg1['Age_Group']=fg1.Age.apply(lambda x: get_Age_GR(x))

# %%
fg2=pd.DataFrame(fg1.groupby(['Age_Group'])['Survived'].aggregate(np.mean))

print(fg2)
# Out:
#            Survived
# Age_Group
# Взрослый   0.391608
# Ребенок    0.573529
# Старый     0.364865

# %%
'Pclass','Sex'
fg3=fg1.groupby(['Pclass','Sex','Age_Group'])['Survived'].aggregate(np.mean).to_frame()

print(fg3)
# Out:
#                           Survived
# Pclass Sex     Age_Group
# 1      Женщины Взрослый   0.985507
#                Ребенок    0.000000
#                Старый     0.933333
#        Мужчины Взрослый   0.449275
#                Ребенок    1.000000
#                Старый     0.206897
# 2      Женщины Взрослый   0.916667
#                Ребенок    1.000000
#                Старый     0.833333
#        Мужчины Взрослый   0.064935
#                Ребенок    1.000000
#                Старый     0.076923
# 3      Женщины Взрослый   0.448718
#                Ребенок    0.478261
#                Старый     1.000000
#        Мужчины Взрослый   0.136986
#                Ребенок    0.333333
#                Старый     0.000000

# %%
sns.barplot(x='Age_Group', y='Survived', hue='Sex', data=fg1)
plt.ylabel("Вероятность выжить")
plt.title("Вероятность выжить, как функция пола и возраста")
plt.show()

# %%
sns.barplot(x='Age_Group', y='Survived', hue='Pclass', data=fg1)
plt.ylabel("Вероятность выжить")
plt.title("Вероятность выжить, как функция возраста и класса каюты")
plt.show()

# %%
g = sns.factorplot(x="Age_Group", y="Survived", hue="Pclass", col="Sex", data=fg1, kind="bar")
# Out:
# C:\Users\shadr\anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# __Вывод__: Гипотеза верна для первого и второго классов.

# %% [markdown]
# ### Гипотеза 3
#
# __Формулировка__:Вероятность выжить пропорциональна стоимости билета

# %%
# Код для проверки гипотезы
sns_plot = sns.distplot(df['Fare'])
fig = sns_plot.get_figure()

###

# %%
sns_plot = sns.distplot(df[df['Pclass']==1]['Fare'])
fig = sns_plot.get_figure()

# %%
sns_plot = sns.distplot(df[df['Pclass']==2]['Fare'])
fig = sns_plot.get_figure()

# %%
sns_plot = sns.distplot(df[df['Pclass']==3]['Fare'])
fig = sns_plot.get_figure()

# %%
# Исследуем особенности набора данных. Предположения об искажающих факторах:
# 1) бесплатные пассажиры
# 2) стоимость билета зависит от места посадки; 
# 3) для семьи выписывался один билет на всех



# 1)Пассажиры с бесплатными билетами
df[df['Fare']==0].groupby(['Pclass','Sex','Embarked']).count()

#Все сели в 'S', все мужчины, присутствуют во всех трех классах.
# После учета остальных особенностей заменим на медианные значения для своих классов
# Смотрим  вначале п.3
# Out:
#                          Unnamed: 0  PassengerId  Survived  Name  Age  SibSp  \
# Pclass Sex     Embarked
# 1      Мужчины S                  5            5         5     5    3      5
# 2      Мужчины S                  6            6         6     6    0      6
# 3      Мужчины S                  4            4         4     4    4      4
#
#                          Parch  Ticket  Fare  Cabin
# Pclass Sex     Embarked
# 1      Мужчины S             5       5     5      3
# 2      Мужчины S             6       6     6      0
# 3      Мужчины S             4       4     4      0

# %%
# исследуем набор без бесплатных пассажиров
df[df['Fare']!=0].groupby(['Pclass','Embarked'])['Fare'].aggregate([min, np.mean,np.median, max, np.std])
#неожиданно! Судно отправлялось из S с заходом в С, далее Q  и через океан. 
#Ожидалось что средняя и медианная цена будет максимальной в S и минимальной в Q/
# Out:
#                      min        mean   median       max        std
# Pclass Embarked
# 1      C         26.5500  104.718529  78.2667  512.3292  99.093935
#        Q         90.0000   90.000000  90.0000   90.0000   0.000000
#        S          5.0000   73.248668  52.5542  263.0000  58.212627
# 2      C         12.0000   25.358335  24.0000   41.5792  11.345067
#        Q         12.3500   12.350000  12.3500   12.3500   0.000000
#        S         10.5000   21.099367  14.5000   73.5000  13.285582
# 3      C          4.0125   11.214083   7.8958   22.3583   4.871528
#        Q          6.7500   11.183393   7.7500   29.1250   6.721677
#        S          6.2375   14.811923   8.0500   69.5500  13.259006

# %%
df[df['Cabin']=='B51 B53 B55']
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 679         679          680         1       1
# 872         872          873         0       1
#
#                                    Name      Sex   Age  SibSp  Parch  \
# 679  Cardeza, Mr. Thomas Drake Martinez  Мужчины  36.0      0      1
# 872            Carlsson, Mr. Frans Olof  Мужчины  33.0      0      0
#
#        Ticket      Fare        Cabin Embarked
# 679  PC 17755  512.3292  B51 B53 B55        C
# 872       695    5.0000  B51 B53 B55        S

# %%
df[df['Ticket']=='PC 17755']
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 258         258          259         1       1
# 679         679          680         1       1
# 737         737          738         1       1
#
#                                    Name      Sex   Age  SibSp  Parch  \
# 258                    Ward, Miss. Anna  Женщины  35.0      0      0
# 679  Cardeza, Mr. Thomas Drake Martinez  Мужчины  36.0      0      1
# 737              Lesurer, Mr. Gustave J  Мужчины  35.0      0      0
#
#        Ticket      Fare        Cabin Embarked
# 258  PC 17755  512.3292          NaN        C
# 679  PC 17755  512.3292  B51 B53 B55        C
# 737  PC 17755  512.3292         B101        C

# %%
#Считаем количество пассажиров на одном билете
TC=pd.DataFrame(df2.groupby(['Ticket']).PassengerId.count())
TC.rename(columns={'PassengerId':'CountT'})
# Out:
#              CountT
# Ticket
# 110152            3
# 110413            3
# 110465            2
# 110564            1
# 110813            1
# ...             ...
# W./C. 6608        4
# W./C. 6609        1
# W.E.P. 5734       1
# W/C 14208         1
# WE/P 5735         2
#
# [681 rows x 1 columns]

# %%
fg4=pd.merge(df2,TC,left_on='Ticket', right_index=True,how='inner')
fg4.head()

# Почему столбец добавился с именем 'PassengerId_y' а не 'CountT'???? надо было добавить , inplace=False
# Out:
#      Unnamed: 0  PassengerId_x  Survived  Pclass  \
# 0             0              1         0       3
# 1             1              2         1       1
# 2             2              3         1       3
# 3             3              4         1       1
# 137         137            138         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 137                        Futrelle, Mr. Jacques Heath    male  37.0      1
#
#      Parch            Ticket     Fare Cabin Embarked  PassengerId_y
# 0        0         A/5 21171   7.2500   NaN        S              1
# 1        0          PC 17599  71.2833   C85        C              1
# 2        0  STON/O2. 3101282   7.9250   NaN        S              1
# 3        0            113803  53.1000  C123        S              2
# 137      0            113803  53.1000  C123        S              2

# %%
#Пересчитываем стоимость проезда
fg4['Fare']=fg4['Fare']/fg4['PassengerId_y']

# %%
fg4[fg4['Fare']!=0].groupby(['Pclass','Embarked'])['Fare'].aggregate([min, np.mean,np.median, max, np.std])
# Out:
#                      min       mean     median       max        std
# Pclass Embarked
# 1      C         15.5000  54.016585  41.085400  211.5000  37.093842
#        Q         45.0000  45.000000  45.000000   45.0000   0.000000
#        S          5.0000  38.254634  30.000000  221.7792  22.241384
# 2      C         12.0000  15.109312  13.859733   27.7208   3.755211
#        Q         12.3500  12.350000  12.350000   12.3500   0.000000
#        S          5.2500  13.654747  13.000000   32.5000   5.337729
# 3      C          4.0125   7.968377   7.229200   21.6792   2.687219
#        Q          5.8250   7.925754   7.750000   15.5000   1.551887
#        S          3.7111   8.233778   7.895800   22.5250   2.334056

# %%
fg4[fg4['Pclass']==1].hist(column='Fare', bins=40, density=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023A64F7FD60>]],
#       dtype=object)

# %%
# Смотрим хвосты слева
fg4[(fg4['Fare']<25.0) & (fg4['Fare']!=0) & (fg4['Pclass']==1)]
# Out:
#      Unnamed: 0  PassengerId_x  Survived  Pclass                      Name  \
# 270         270            271         0       1     Cairns, Mr. Alexander
# 842         842            843         1       1   Serepeca, Miss. Augusta
# 872         872            873         0       1  Carlsson, Mr. Frans Olof
#
#         Sex   Age  SibSp  Parch  Ticket  Fare        Cabin Embarked  \
# 270    male   NaN      0      0  113798  15.5          NaN        S
# 842  female  30.0      0      0  113798  15.5          NaN        C
# 872    male  33.0      0      0     695   5.0  B51 B53 B55        S
#
#      PassengerId_y
# 270              2
# 842              2
# 872              1

# %%
# По видимому 873 пассажир не имеет отношения к первому классу - все остальные пассажиры 
# в этих трех номерах заплатили более 180. Скорее всего это слуга

# %%
fg4[fg4['Pclass']==2].hist(column='Fare', bins=40, density=True)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023A64D31CA0>]],
#       dtype=object)

# %%
# Смотрим хвосты слева

fg4[(fg4['Fare']<10.0) & (fg4['Fare']!=0)& (fg4['Pclass']==2)]
# Out:
#      Unnamed: 0  PassengerId_x  Survived  Pclass  \
# 58           58             59         1       2
# 450         450            451         0       2
# 472         472            473         1       2
# 148         148            149         0       2
# 193         193            194         1       2
# 340         340            341         1       2
# 237         237            238         1       2
# 637         637            638         0       2
# 801         801            802         1       2
# 247         247            248         1       2
# 755         755            756         1       2
# 272         272            273         1       2
# 446         446            447         1       2
# 314         314            315         0       2
# 440         440            441         1       2
# 535         535            536         1       2
# 407         407            408         1       2
# 437         437            438         1       2
# 831         831            832         1       2
# 714         714            715         0       2
# 800         800            801         0       2
# 772         772            773         0       2
# 841         841            842         0       2
#
#                                             Name     Sex    Age  SibSp  Parch  \
# 58                  West, Miss. Constance Mirium  female   5.00      1      2
# 450                        West, Mr. Edwy Arthur    male  36.00      1      2
# 472      West, Mrs. Edwy Arthur (Ada Mary Worth)  female  33.00      1      2
# 148     Navratil, Mr. Michel ("Louis M Hoffman")    male  36.50      0      2
# 193                   Navratil, Master. Michel M    male   3.00      1      1
# 340               Navratil, Master. Edmond Roger    male   2.00      1      1
# 237             Collyer, Miss. Marjorie "Lottie"  female   8.00      0      2
# 637                          Collyer, Mr. Harvey    male  31.00      1      1
# 801  Collyer, Mrs. Harvey (Charlotte Annie Tate)  female  31.00      1      1
# 247              Hamalainen, Mrs. William (Anna)  female  24.00      0      2
# 755                    Hamalainen, Master. Viljo    male   0.67      1      1
# 272    Mellinger, Mrs. (Elizabeth Anne Maidment)  female  41.00      0      1
# 446            Mellinger, Miss. Madeleine Violet  female  13.00      0      1
# 314                           Hart, Mr. Benjamin    male  43.00      1      1
# 440  Hart, Mrs. Benjamin (Esther Ada Bloomfield)  female  45.00      1      1
# 535                       Hart, Miss. Eva Miriam  female   7.00      0      2
# 407               Richards, Master. William Rowe    male   3.00      1      1
# 437        Richards, Mrs. Sidney (Emily Hocking)  female  24.00      2      3
# 831              Richards, Master. George Sibley    male   0.83      1      1
# 714                        Greenberg, Mr. Samuel    male  52.00      0      0
# 800                         Ponesell, Mr. Martin    male  34.00      0      0
# 772                            Mack, Mrs. (Mary)  female  57.00      0      0
# 841                     Mudd, Mr. Thomas Charles    male  16.00      0      0
#
#            Ticket      Fare Cabin Embarked  PassengerId_y
# 58     C.A. 34651  9.250000   NaN        S              3
# 450    C.A. 34651  9.250000   NaN        S              3
# 472    C.A. 34651  9.250000   NaN        S              3
# 148        230080  8.666667    F2        S              3
# 193        230080  8.666667    F2        S              3
# 340        230080  8.666667    F2        S              3
# 237    C.A. 31921  8.750000   NaN        S              3
# 637    C.A. 31921  8.750000   NaN        S              3
# 801    C.A. 31921  8.750000   NaN        S              3
# 247        250649  7.250000   NaN        S              2
# 755        250649  7.250000   NaN        S              2
# 272        250644  9.750000   NaN        S              2
# 446        250644  9.750000   NaN        S              2
# 314  F.C.C. 13529  8.750000   NaN        S              3
# 440  F.C.C. 13529  8.750000   NaN        S              3
# 535  F.C.C. 13529  8.750000   NaN        S              3
# 407         29106  6.250000   NaN        S              3
# 437         29106  6.250000   NaN        S              3
# 831         29106  6.250000   NaN        S              3
# 714        250647  6.500000   NaN        S              2
# 800        250647  6.500000   NaN        S              2
# 772   S.O./P.P. 3  5.250000   E77        S              2
# 841   S.O./P.P. 3  5.250000   NaN        S              2

# %%
# По списку видно что 1 из путешествующих по билету может ехать бесплатно - младенец, сопровождающее лицо
#  Корректируем на 1
#Пересчитываем стоимость проезда
mask=(fg4['Fare']<10.0) & (fg4['Fare']!=0) & (fg4['Pclass']==2)

fg4.loc[mask,'Fare']=fg4['Fare']*fg4['PassengerId_y']/(fg4['PassengerId_y']-1)

# %%
# Смотрим хвосты слева

fg4.loc[mask]
# Out:
#      Unnamed: 0  PassengerId_x  Survived  Pclass  \
# 58           58             59         1       2
# 450         450            451         0       2
# 472         472            473         1       2
# 148         148            149         0       2
# 193         193            194         1       2
# 340         340            341         1       2
# 237         237            238         1       2
# 637         637            638         0       2
# 801         801            802         1       2
# 247         247            248         1       2
# 755         755            756         1       2
# 272         272            273         1       2
# 446         446            447         1       2
# 314         314            315         0       2
# 440         440            441         1       2
# 535         535            536         1       2
# 407         407            408         1       2
# 437         437            438         1       2
# 831         831            832         1       2
# 714         714            715         0       2
# 800         800            801         0       2
# 772         772            773         0       2
# 841         841            842         0       2
#
#                                             Name     Sex    Age  SibSp  Parch  \
# 58                  West, Miss. Constance Mirium  female   5.00      1      2
# 450                        West, Mr. Edwy Arthur    male  36.00      1      2
# 472      West, Mrs. Edwy Arthur (Ada Mary Worth)  female  33.00      1      2
# 148     Navratil, Mr. Michel ("Louis M Hoffman")    male  36.50      0      2
# 193                   Navratil, Master. Michel M    male   3.00      1      1
# 340               Navratil, Master. Edmond Roger    male   2.00      1      1
# 237             Collyer, Miss. Marjorie "Lottie"  female   8.00      0      2
# 637                          Collyer, Mr. Harvey    male  31.00      1      1
# 801  Collyer, Mrs. Harvey (Charlotte Annie Tate)  female  31.00      1      1
# 247              Hamalainen, Mrs. William (Anna)  female  24.00      0      2
# 755                    Hamalainen, Master. Viljo    male   0.67      1      1
# 272    Mellinger, Mrs. (Elizabeth Anne Maidment)  female  41.00      0      1
# 446            Mellinger, Miss. Madeleine Violet  female  13.00      0      1
# 314                           Hart, Mr. Benjamin    male  43.00      1      1
# 440  Hart, Mrs. Benjamin (Esther Ada Bloomfield)  female  45.00      1      1
# 535                       Hart, Miss. Eva Miriam  female   7.00      0      2
# 407               Richards, Master. William Rowe    male   3.00      1      1
# 437        Richards, Mrs. Sidney (Emily Hocking)  female  24.00      2      3
# 831              Richards, Master. George Sibley    male   0.83      1      1
# 714                        Greenberg, Mr. Samuel    male  52.00      0      0
# 800                         Ponesell, Mr. Martin    male  34.00      0      0
# 772                            Mack, Mrs. (Mary)  female  57.00      0      0
# 841                     Mudd, Mr. Thomas Charles    male  16.00      0      0
#
#            Ticket    Fare Cabin Embarked  PassengerId_y
# 58     C.A. 34651  13.875   NaN        S              3
# 450    C.A. 34651  13.875   NaN        S              3
# 472    C.A. 34651  13.875   NaN        S              3
# 148        230080  13.000    F2        S              3
# 193        230080  13.000    F2        S              3
# 340        230080  13.000    F2        S              3
# 237    C.A. 31921  13.125   NaN        S              3
# 637    C.A. 31921  13.125   NaN        S              3
# 801    C.A. 31921  13.125   NaN        S              3
# 247        250649  14.500   NaN        S              2
# 755        250649  14.500   NaN        S              2
# 272        250644  19.500   NaN        S              2
# 446        250644  19.500   NaN        S              2
# 314  F.C.C. 13529  13.125   NaN        S              3
# 440  F.C.C. 13529  13.125   NaN        S              3
# 535  F.C.C. 13529  13.125   NaN        S              3
# 407         29106   9.375   NaN        S              3
# 437         29106   9.375   NaN        S              3
# 831         29106   9.375   NaN        S              3
# 714        250647  13.000   NaN        S              2
# 800        250647  13.000   NaN        S              2
# 772   S.O./P.P. 3  10.500   E77        S              2
# 841   S.O./P.P. 3  10.500   NaN        S              2

# %%
#смотрим хвосты справа для 2 класса
mask=(fg4['Fare']>16.0) & (fg4['Pclass']==2) & (fg4['PassengerId_y']>1)
fg4.loc[mask]
# Out:
#      Unnamed: 0  PassengerId_x  Survived  Pclass  \
# 145         145            146         0       2
# 549         549            550         1       2
# 183         183            184         1       2
# 618         618            619         1       2
# 272         272            273         1       2
# 446         446            447         1       2
# 615         615            616         1       2
# 754         754            755         1       2
# 670         670            671         1       2
# 684         684            685         0       2
# 817         817            818         0       2
# 827         827            828         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 145                       Nicholls, Mr. Joseph Charles    male  19.0      1
# 549                     Davies, Master. John Morgan Jr    male   8.0      1
# 183                          Becker, Master. Richard F    male   1.0      2
# 618                        Becker, Miss. Marion Louise  female   4.0      2
# 272          Mellinger, Mrs. (Elizabeth Anne Maidment)  female  41.0      0
# 446                  Mellinger, Miss. Madeleine Violet  female  13.0      0
# 615                                Herman, Miss. Alice  female  24.0      1
# 754                   Herman, Mrs. Samuel (Jane Laver)  female  48.0      1
# 670  Brown, Mrs. Thomas William Solomon (Elizabeth ...  female  40.0      1
# 684                  Brown, Mr. Thomas William Solomon    male  60.0      1
# 817                                 Mallet, Mr. Albert    male  31.0      1
# 827                              Mallet, Master. Andre    male   1.0      0
#
#      Parch           Ticket     Fare Cabin Embarked  PassengerId_y
# 145      1       C.A. 33112  18.3750   NaN        S              2
# 549      1       C.A. 33112  18.3750   NaN        S              2
# 183      1           230136  19.5000    F4        S              2
# 618      1           230136  19.5000    F4        S              2
# 272      1           250644  19.5000   NaN        S              2
# 446      1           250644  19.5000   NaN        S              2
# 615      2           220845  32.5000   NaN        S              2
# 754      2           220845  32.5000   NaN        S              2
# 670      1            29750  19.5000   NaN        S              2
# 684      1            29750  19.5000   NaN        S              2
# 817      1  S.C./PARIS 2079  18.5021   NaN        C              2
# 827      2  S.C./PARIS 2079  18.5021   NaN        C              2

# %%
mask1=(fg4['Ticket']=='220845')
fg4.loc[mask1]
# Out:
#      Unnamed: 0  PassengerId_x  Survived  Pclass  \
# 615         615            616         1       2
# 754         754            755         1       2
#
#                                  Name     Sex   Age  SibSp  Parch  Ticket  \
# 615               Herman, Miss. Alice  female  24.0      1      2  220845
# 754  Herman, Mrs. Samuel (Jane Laver)  female  48.0      1      2  220845
#
#      Fare Cabin Embarked  PassengerId_y
# 615  32.5   NaN        S              2
# 754  32.5   NaN        S              2

# %%
fg4[(fg4['Fare']==0)]
# Out:
#      Unnamed: 0  PassengerId_x  Survived  Pclass  \
# 179         179            180         0       3
# 271         271            272         1       3
# 302         302            303         0       3
# 597         597            598         0       3
# 263         263            264         0       1
# 277         277            278         0       2
# 413         413            414         0       2
# 466         466            467         0       2
# 481         481            482         0       2
# 633         633            634         0       1
# 674         674            675         0       2
# 732         732            733         0       2
# 806         806            807         0       1
# 815         815            816         0       1
# 822         822            823         0       1
#
#                                  Name   Sex   Age  SibSp  Parch  Ticket  Fare  \
# 179               Leonard, Mr. Lionel  male  36.0      0      0    LINE   0.0
# 271      Tornquist, Mr. William Henry  male  25.0      0      0    LINE   0.0
# 302   Johnson, Mr. William Cahoone Jr  male  19.0      0      0    LINE   0.0
# 597               Johnson, Mr. Alfred  male  49.0      0      0    LINE   0.0
# 263             Harrison, Mr. William  male  40.0      0      0  112059   0.0
# 277       Parkes, Mr. Francis "Frank"  male   NaN      0      0  239853   0.0
# 413    Cunningham, Mr. Alfred Fleming  male   NaN      0      0  239853   0.0
# 466             Campbell, Mr. William  male   NaN      0      0  239853   0.0
# 481  Frost, Mr. Anthony Wood "Archie"  male   NaN      0      0  239854   0.0
# 633     Parr, Mr. William Henry Marsh  male   NaN      0      0  112052   0.0
# 674        Watson, Mr. Ennis Hastings  male   NaN      0      0  239856   0.0
# 732              Knight, Mr. Robert J  male   NaN      0      0  239855   0.0
# 806            Andrews, Mr. Thomas Jr  male  39.0      0      0  112050   0.0
# 815                  Fry, Mr. Richard  male   NaN      0      0  112058   0.0
# 822   Reuchlin, Jonkheer. John George  male  38.0      0      0   19972   0.0
#
#     Cabin Embarked  PassengerId_y
# 179   NaN        S              4
# 271   NaN        S              4
# 302   NaN        S              4
# 597   NaN        S              4
# 263   B94        S              1
# 277   NaN        S              3
# 413   NaN        S              3
# 466   NaN        S              3
# 481   NaN        S              1
# 633   NaN        S              1
# 674   NaN        S              1
# 732   NaN        S              1
# 806   A36        S              1
# 815  B102        S              1
# 822   NaN        S              1

# %%
# Вновь исследуем набор без бесплатных пассажиров
fg4[fg4['Fare']!=0].groupby(['Pclass','Embarked'])['Fare'].aggregate([min, np.mean,np.median, max, np.std])
# Out:
#                      min       mean     median       max        std
# Pclass Embarked
# 1      C         15.5000  54.016585  41.085400  211.5000  37.093842
#        Q         45.0000  45.000000  45.000000   45.0000   0.000000
#        S          5.0000  38.254634  30.000000  221.7792  22.241384
# 2      C         12.0000  15.109312  13.859733   27.7208   3.755211
#        Q         12.3500  12.350000  12.350000   12.3500   0.000000
#        S          9.3750  14.414241  13.000000   32.5000   4.875990
# 3      C          4.0125   7.968377   7.229200   21.6792   2.687219
#        Q          5.8250   7.925754   7.750000   15.5000   1.551887
#        S          3.7111   8.233778   7.895800   22.5250   2.334056

# %%
# считаем медианы для пассажиров с нулевой стоимостью
mask=(fg4['Fare']!=0) & (fg4['Embarked']=='S') & (fg4['Sex']=='male')
MEd_Fare =fg4[mask].groupby('Pclass')['Fare'].aggregate(np.median).to_frame()
print(MEd_Fare)
# Out:
#            Fare
# Pclass
# 1       30.0000
# 2       13.0000
# 3        7.8958

# %%
for i in range(1,4):
    mask=(fg4['Fare']==0) & (fg4['Pclass']==i)
    fg4.loc[mask,'Fare']=MEd_Fare.loc[i].Fare

# %%
mask=(df['Fare']==0)
print(fg4.loc[mask])
# Out:
#      Unnamed: 0  PassengerId_x  Survived  Pclass  \
# 179         179            180         0       3
# 271         271            272         1       3
# 302         302            303         0       3
# 597         597            598         0       3
# 263         263            264         0       1
# 277         277            278         0       2
# 413         413            414         0       2
# 466         466            467         0       2
# 481         481            482         0       2
# 633         633            634         0       1
# 674         674            675         0       2
# 732         732            733         0       2
# 806         806            807         0       1
# 815         815            816         0       1
# 822         822            823         0       1
#
#                                  Name   Sex   Age  SibSp  Parch  Ticket  \
# 179               Leonard, Mr. Lionel  male  36.0      0      0    LINE
# 271      Tornquist, Mr. William Henry  male  25.0      0      0    LINE
# 302   Johnson, Mr. William Cahoone Jr  male  19.0      0      0    LINE
# 597               Johnson, Mr. Alfred  male  49.0      0      0    LINE
# 263             Harrison, Mr. William  male  40.0      0      0  112059
# 277       Parkes, Mr. Francis "Frank"  male   NaN      0      0  239853
# 413    Cunningham, Mr. Alfred Fleming  male   NaN      0      0  239853
# 466             Campbell, Mr. William  male   NaN      0      0  239853
# 481  Frost, Mr. Anthony Wood "Archie"  male   NaN      0      0  239854
# 633     Parr, Mr. William Henry Marsh  male   NaN      0      0  112052
# 674        Watson, Mr. Ennis Hastings  male   NaN      0      0  239856
# 732              Knight, Mr. Robert J  male   NaN      0      0  239855
# 806            Andrews, Mr. Thomas Jr  male  39.0      0      0  112050
# 815                  Fry, Mr. Richard  male   NaN      0      0  112058
# 822   Reuchlin, Jonkheer. John George  male  38.0      0      0   19972
#
#         Fare Cabin Embarked  PassengerId_y
# 179   7.8958   NaN        S              4
# 271   7.8958   NaN        S              4
# 302   7.8958   NaN        S              4
# 597   7.8958   NaN        S              4
# 263  30.0000   B94        S              1
# 277  13.0000   NaN        S              3
# 413  13.0000   NaN        S              3
# 466  13.0000   NaN        S              3
# 481  13.0000   NaN        S              1
# 633  30.0000   NaN        S              1
# 674  13.0000   NaN        S              1
# 732  13.0000   NaN        S              1
# 806  30.0000   A36        S              1
# 815  30.0000  B102        S              1
# 822  30.0000   NaN        S              1

# %%
cut_labels = ['4-5', '5-6', '6-7', '7-8', '8-10', '10-12', '12-14', '14-16', '16-18', '18-20', '20-25', '25-30', '30-35', '35-45', '45-55', '55-1000']
cut_bins = [4, 5, 6, 7, 8, 10, 12, 14, 16, 18, 20, 25, 30, 35, 45, 55, 1000]

fg4['cut_ex1'] = pd.cut(fg4['Fare'], bins=cut_bins, labels=cut_labels)
fg4.head()
# Out:
#      Unnamed: 0  PassengerId_x  Survived  Pclass  \
# 0             0              1         0       3
# 1             1              2         1       1
# 2             2              3         1       3
# 3             3              4         1       1
# 137         137            138         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 137                        Futrelle, Mr. Jacques Heath    male  37.0      1
#
#      Parch            Ticket     Fare Cabin Embarked  PassengerId_y  cut_ex1
# 0        0         A/5 21171   7.2500   NaN        S              1      7-8
# 1        0          PC 17599  71.2833   C85        C              1  55-1000
# 2        0  STON/O2. 3101282   7.9250   NaN        S              1      7-8
# 3        0            113803  26.5500  C123        S              2    25-30
# 137      0            113803  26.5500  C123        S              2    25-30

# %%
plt.subplots(figsize=(12,6))
sns.barplot(x='cut_ex1' , y='Survived' , data = fg4)
plt.ylabel("Выживаемость")
plt.title("Выживаемость от цены билета")
plt.show()

# %% [markdown]
# __Вывод__:

# %%
# Чем выше цена билета, тем выше шансы выжить.

# %% [markdown]
# ### Вывод исследования:

# %% [markdown]
# #
# 1.Чем выше класс каюты тем выше шансы выжить.
# 2.Чем выше стоимость билета тем выше шансы выжить
# 3.В 1 и 2 классах самые высокие шансы выжить имели дети вне зависимости от пола, женщины  вне зависимости от возраста. Наименьшие - старики. В 3 классе - самые высокие шансы выжить имели женщины, затем дети, наименьшие - взрослые мужчины.
